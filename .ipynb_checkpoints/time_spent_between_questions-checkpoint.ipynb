# %%
import os
# ^^^ pyforest auto-imports - don't write above this line
import math
import numpy as np
from scipy import stats
import pandas as pd
import seaborn as sns

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abebu\\Dropbox\\World Bank\\Industrial Workers Compensation\\Piloting\\Time-spent-between-survey-questions-'

# %%
os.chdir("C://Users/abebu/Dropbox/World Bank/Industrial Workers Compensation/Piloting")

# %%
pilot=pd.read_csv('interview_actions.csv', header=0, index_col=0)
pilot.head()
# Out:
#                                    interview__id        date      time  \
# interview__key
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:10:26
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:18:48
#
#                              action     originator         role  \
# interview__key
# 08-66-57-54                 Created  samrawitWonde  Interviewer
# 08-66-57-54      SupervisorAssigned  samrawitWonde  Interviewer
# 08-66-57-54     InterviewerAssigned  samrawitWonde  Interviewer
# 08-66-57-54          FirstAnswerSet  samrawitWonde  Interviewer
# 08-66-57-54                  Paused  samrawitWonde  Interviewer
#
#                responsible__name responsible__role
# interview__key
# 08-66-57-54        samrawitWonde       Interviewer
# 08-66-57-54         seada_redwan        Supervisor
# 08-66-57-54        samrawitWonde       Interviewer
# 08-66-57-54        samrawitWonde       Interviewer
# 08-66-57-54        samrawitWonde       Interviewer

# %%
pilot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 208 entries, 08-66-57-54 to 03-39-02-48
# Data columns (total 8 columns):
# interview__id        208 non-null object
# date                 208 non-null object
# time                 208 non-null object
# action               208 non-null object
# originator           208 non-null object
# role                 208 non-null object
# responsible__name    204 non-null object
# responsible__role    204 non-null object
# dtypes: object(8)
# memory usage: 14.6+ KB

# %%
pilot
# Out:
#                                    interview__id        date      time  \
# interview__key
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:10:26
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:18:48
# ...                                          ...         ...       ...
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:07:43
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:13:10
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:14:30
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:22:56
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  13:06:49
#
#                                action     originator           role  \
# interview__key
# 08-66-57-54                   Created  samrawitWonde    Interviewer
# 08-66-57-54        SupervisorAssigned  samrawitWonde    Interviewer
# 08-66-57-54       InterviewerAssigned  samrawitWonde    Interviewer
# 08-66-57-54            FirstAnswerSet  samrawitWonde    Interviewer
# 08-66-57-54                    Paused  samrawitWonde    Interviewer
# ...                               ...            ...            ...
# 03-39-02-48                 Completed    beza_eshetu    Interviewer
# 03-39-02-48        OpenedBySupervisor   seada_redwan     Supervisor
# 03-39-02-48        ClosedBySupervisor   seada_redwan     Supervisor
# 03-39-02-48      ApprovedBySupervisor   seada_redwan     Supervisor
# 03-39-02-48     ApprovedByHeadquarter         mesfin  Administrator
#
#                responsible__name responsible__role
# interview__key
# 08-66-57-54        samrawitWonde       Interviewer
# 08-66-57-54         seada_redwan        Supervisor
# 08-66-57-54        samrawitWonde       Interviewer
# 08-66-57-54        samrawitWonde       Interviewer
# 08-66-57-54        samrawitWonde       Interviewer
# ...                          ...               ...
# 03-39-02-48         seada_redwan        Supervisor
# 03-39-02-48         seada_redwan        Supervisor
# 03-39-02-48         seada_redwan        Supervisor
# 03-39-02-48     any headquarters       Headquarter
# 03-39-02-48                  NaN               NaN
#
# [208 rows x 8 columns]

# %%
#time diffrence (in minutes) betwen two consecuative timestamp
pilot['time_diff'] = pd.to_timedelta(pilot['time'].astype(str)).diff(-1).dt.total_seconds().div(60)

# %%
pilot
# Out:
#                                    interview__id        date      time  \
# interview__key
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:05:21
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:10:26
# 08-66-57-54     e47dd14e06eb405aa6511547bf17b217  2020-04-23  09:18:48
# ...                                          ...         ...       ...
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:07:43
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:13:10
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:14:30
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  12:22:56
# 03-39-02-48     6ceeae68902147aeb89065c23b603d35  2020-04-27  13:06:49
#
#                                action     originator           role  \
# interview__key
# 08-66-57-54                   Created  samrawitWonde    Interviewer
# 08-66-57-54        SupervisorAssigned  samrawitWonde    Interviewer
# 08-66-57-54       InterviewerAssigned  samrawitWonde    Interviewer
# 08-66-57-54            FirstAnswerSet  samrawitWonde    Interviewer
# 08-66-57-54                    Paused  samrawitWonde    Interviewer
# ...                               ...            ...            ...
# 03-39-02-48                 Completed    beza_eshetu    Interviewer
# 03-39-02-48        OpenedBySupervisor   seada_redwan     Supervisor
# 03-39-02-48        ClosedBySupervisor   seada_redwan     Supervisor
# 03-39-02-48      ApprovedBySupervisor   seada_redwan     Supervisor
# 03-39-02-48     ApprovedByHeadquarter         mesfin  Administrator
#
#                responsible__name responsible__role  time_diff
# interview__key
# 08-66-57-54        samrawitWonde       Interviewer   0.000000
# 08-66-57-54         seada_redwan        Supervisor   0.000000
# 08-66-57-54        samrawitWonde       Interviewer  -5.083333
# 08-66-57-54        samrawitWonde       Interviewer  -8.366667
# 08-66-57-54        samrawitWonde       Interviewer  -2.166667
# ...                          ...               ...        ...
# 03-39-02-48         seada_redwan        Supervisor  -5.450000
# 03-39-02-48         seada_redwan        Supervisor  -1.333333
# 03-39-02-48         seada_redwan        Supervisor  -8.433333
# 03-39-02-48     any headquarters       Headquarter -43.883333
# 03-39-02-48                  NaN               NaN        NaN
#
# [208 rows x 9 columns]

# %%
#pilot.to_csv('timediff.csv')
